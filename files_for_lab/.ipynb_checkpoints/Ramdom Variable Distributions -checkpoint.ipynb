# %% [markdown]
# # GO TO THE END OF THE LAB TO SEE LAB RAMDOM VARIABLE DISTRIBUTION !!!

# %%
# I create a new notebook so import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import Data
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
display(customer_df.shape)
display(customer_df.head())
display(customer_df.tail())
# Out:
# (9134, 24)
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
# 2                            38                         0                   2
# 3                            65                         0                   7
# 4                            44                         0                   1
#
#       Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
# 2   Personal Auto   Personal L3            Offer1          Agent
# 3  Corporate Auto  Corporate L2            Offer1    Call Center
# 4   Personal Auto   Personal L1            Offer1          Agent
#
#   Total Claim Amount  Vehicle Class Vehicle Size
# 0         384.811147   Two-Door Car      Medsize
# 1        1131.464935  Four-Door Car      Medsize
# 2         566.472247   Two-Door Car      Medsize
# 3         529.881344            SUV      Medsize
# 4         138.130879  Four-Door Car      Medsize
#
# [5 rows x 24 columns]
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# 9129  Bachelor           2/10/11         Employed      M   71941  ...
# 9130   College           2/12/11         Employed      F   21604  ...
# 9131  Bachelor            2/6/11       Unemployed      M       0  ...
# 9132   College            2/3/11         Employed      M   21941  ...
# 9133   College           2/14/11       Unemployed      M       0  ...
#
#      Months Since Policy Inception Number of Open Complaints  \
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# 9129            Web         198.234764  Four-Door Car      Medsize
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
#Checking NaN Values
customer_df.isna().sum()
# Out:
# Customer                         0
# State                            0
# Customer Lifetime Value          0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
#Standarizing Headers 
def standardize_header(dataframe):
    dataframe.columns = [c.lower().replace(' ', '_') for c in dataframe.columns]

standardize_header(customer_df)

# %%
customer_df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
customer_df = customer_df.rename(columns={'employmentstatus':'employment_status'})

# %%
customer_df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employment_status', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
#Checking Dtypes
customer_df.dtypes
# Out:
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employment_status                 object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim            int64
# months_since_policy_inception      int64
# number_of_open_complaints          int64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# vehicle_class                     object
# vehicle_size                      object
# dtype: object

# %%
#Splitting into Categorical and Numerical variables
categorical_df = customer_df.select_dtypes('object')
numerical_df = customer_df.select_dtypes(np.number)

# %%
# Cleaning Categoricals
categorical_df
# Out:
#      customer       state response  coverage education effective_to_date  \
# 0     BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1     QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2     AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3     WW63253  California       No     Basic  Bachelor           1/20/11
# 4     HB64268  Washington       No     Basic  Bachelor            2/3/11
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor           2/10/11
# 9130  PK87824  California      Yes  Extended   College           2/12/11
# 9131  TD14365  California       No  Extended  Bachelor            2/6/11
# 9132  UP19263  California       No  Extended   College            2/3/11
# 9133  Y167826  California       No  Extended   College           2/14/11
#
#      employment_status gender location_code marital_status     policy_type  \
# 0             Employed      F      Suburban        Married  Corporate Auto
# 1           Unemployed      F      Suburban         Single   Personal Auto
# 2             Employed      F      Suburban        Married   Personal Auto
# 3           Unemployed      M      Suburban        Married  Corporate Auto
# 4             Employed      M         Rural         Single   Personal Auto
# ...                ...    ...           ...            ...             ...
# 9129          Employed      M         Urban        Married   Personal Auto
# 9130          Employed      F      Suburban       Divorced  Corporate Auto
# 9131        Unemployed      M      Suburban         Single  Corporate Auto
# 9132          Employed      M      Suburban        Married   Personal Auto
# 9133        Unemployed      M      Suburban         Single  Corporate Auto
#
#             policy renew_offer_type sales_channel  vehicle_class vehicle_size
# 0     Corporate L3           Offer1         Agent   Two-Door Car      Medsize
# 1      Personal L3           Offer3         Agent  Four-Door Car      Medsize
# 2      Personal L3           Offer1         Agent   Two-Door Car      Medsize
# 3     Corporate L2           Offer1   Call Center            SUV      Medsize
# 4      Personal L1           Offer1         Agent  Four-Door Car      Medsize
# ...            ...              ...           ...            ...          ...
# 9129   Personal L1           Offer2           Web  Four-Door Car      Medsize
# 9130  Corporate L3           Offer1        Branch  Four-Door Car      Medsize
# 9131  Corporate L2           Offer1        Branch  Four-Door Car      Medsize
# 9132   Personal L2           Offer3        Branch  Four-Door Car        Large
# 9133  Corporate L3           Offer4   Call Center   Two-Door Car      Medsize
#
# [9134 rows x 16 columns]

# %%
for col in categorical_df.columns:
    print(categorical_df[col].unique())
# Out:
# ['BU79786' 'QZ44356' 'AI49188' ... 'TD14365' 'UP19263' 'Y167826']
# ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon']
# ['No' 'Yes']
# ['Basic' 'Extended' 'Premium']
# ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor']
# ['2/24/11' '1/31/11' '2/19/11' '1/20/11' '2/3/11' '1/25/11' '1/18/11'
#  '1/26/11' '2/17/11' '2/21/11' '1/6/11' '2/6/11' '1/10/11' '1/17/11'
#  '1/5/11' '2/27/11' '1/14/11' '1/21/11' '2/5/11' '1/29/11' '2/28/11'
#  '2/12/11' '2/2/11' '2/7/11' '1/22/11' '2/13/11' '1/15/11' '1/8/11'
#  '1/11/11' '1/28/11' '2/8/11' '2/23/11' '1/2/11' '2/16/11' '1/27/11'
#  '1/23/11' '1/9/11' '2/11/11' '2/4/11' '2/1/11' '2/15/11' '2/26/11'
#  '1/16/11' '1/1/11' '2/10/11' '1/24/11' '2/25/11' '1/12/11' '2/9/11'
#  '1/19/11' '1/4/11' '2/14/11' '2/20/11' '2/18/11' '1/3/11' '1/13/11'
#  '1/30/11' '2/22/11' '1/7/11']
# ['Employed' 'Unemployed' 'Medical Leave' 'Disabled' 'Retired']
# ['F' 'M']
# ['Suburban' 'Rural' 'Urban']
# ['Married' 'Single' 'Divorced']
# ['Corporate Auto' 'Personal Auto' 'Special Auto']
# ['Corporate L3' 'Personal L3' 'Corporate L2' 'Personal L1' 'Special L2'
#  'Corporate L1' 'Personal L2' 'Special L1' 'Special L3']
# ['Offer1' 'Offer3' 'Offer2' 'Offer4']
# ['Agent' 'Call Center' 'Web' 'Branch']
# ['Two-Door Car' 'Four-Door Car' 'SUV' 'Luxury SUV' 'Sports Car'
#  'Luxury Car']
# ['Medsize' 'Small' 'Large']

# %%
# Converting the date into datetime format
categorical_df['effective_to_date'] = pd.to_datetime(categorical_df['effective_to_date'])

# %%
#Dropping Customer because it doenst give us any info
categorical_df = categorical_df.drop(['customer'], axis = 1)

# %%
# education grouped Master degree and Doctor's degree into Masters
categorical_df["education"] = np.where(categorical_df.education.isin(['Master','Doctor']),'Masters', categorical_df.education)
categorical_df['education'].value_counts()
# Out:
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Masters                 1083
# Name: education, dtype: int64

# %%
#in 'employment status' : we are grouping medical leaves, disabled and retires in the category 'other'
categorical_df['employment_status'] = np.where(categorical_df['employment_status'].isin(['Medical Leave','Disabled','Retired']) , 'Other', categorical_df['employment_status'])
categorical_df['employment_status'].value_counts()
# Out:
# Employed      5698
# Unemployed    2317
# Other         1119
# Name: employment_status, dtype: int64

# %%
#in 'policy' we have 9 categories that we can actually group on 3 (L1,L2 and L3) and still have the same info
categorical_df['policy'] = categorical_df['policy'].str.replace("\w* ",' ')
categorical_df['policy'].value_counts()
# Out:
# C:\Users\ChristianGardel\AppData\Local\Temp\ipykernel_13548\1708662926.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   categorical_df['policy'] = categorical_df['policy'].str.replace("\w* ",' ')
#  L3    4588
#  L2    2881
#  L1    1665
# Name: policy, dtype: int64

# %%
#in 'vehicule_class' : we group 'luxury SUV', 'Sports' and 'Luxury cars' into a 'premium' category
categorical_df['vehicle_class'] = categorical_df['vehicle_class'].fillna('Premium')
categorical_df['vehicle_class'] = np.where(categorical_df['vehicle_class'].isin(['Luxury SUV','Luxury Car','Sports Car']) , 'Premium', categorical_df['vehicle_class'])
categorical_df['vehicle_class'].value_counts()
# Out:
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Premium           831
# Name: vehicle_class, dtype: int64

# %%
categorical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   state              9134 non-null   object
#  1   response           9134 non-null   object
#  2   coverage           9134 non-null   object
#  3   education          9134 non-null   object
#  4   effective_to_date  9134 non-null   datetime64[ns]
#  5   employment_status  9134 non-null   object
#  6   gender             9134 non-null   object
#  7   location_code      9134 non-null   object
#  8   marital_status     9134 non-null   object
#  9   policy_type        9134 non-null   object
#  10  policy             9134 non-null   object
#  11  renew_offer_type   9134 non-null   object
#  12  sales_channel      9134 non-null   object
#  13  vehicle_class      9134 non-null   object
#  14  vehicle_size       9134 non-null   object
# dtypes: datetime64[ns](1), object(14)
# memory usage: 1.0+ MB

# %%
categorical_df
# Out:
#            state response  coverage education effective_to_date  \
# 0     Washington       No     Basic  Bachelor        2011-02-24
# 1        Arizona       No  Extended  Bachelor        2011-01-31
# 2         Nevada       No   Premium  Bachelor        2011-02-19
# 3     California       No     Basic  Bachelor        2011-01-20
# 4     Washington       No     Basic  Bachelor        2011-02-03
# ...          ...      ...       ...       ...               ...
# 9129  California       No     Basic  Bachelor        2011-02-10
# 9130  California      Yes  Extended   College        2011-02-12
# 9131  California       No  Extended  Bachelor        2011-02-06
# 9132  California       No  Extended   College        2011-02-03
# 9133  California       No  Extended   College        2011-02-14
#
#      employment_status gender location_code marital_status     policy_type  \
# 0             Employed      F      Suburban        Married  Corporate Auto
# 1           Unemployed      F      Suburban         Single   Personal Auto
# 2             Employed      F      Suburban        Married   Personal Auto
# 3           Unemployed      M      Suburban        Married  Corporate Auto
# 4             Employed      M         Rural         Single   Personal Auto
# ...                ...    ...           ...            ...             ...
# 9129          Employed      M         Urban        Married   Personal Auto
# 9130          Employed      F      Suburban       Divorced  Corporate Auto
# 9131        Unemployed      M      Suburban         Single  Corporate Auto
# 9132          Employed      M      Suburban        Married   Personal Auto
# 9133        Unemployed      M      Suburban         Single  Corporate Auto
#
#      policy renew_offer_type sales_channel  vehicle_class vehicle_size
# 0        L3           Offer1         Agent   Two-Door Car      Medsize
# 1        L3           Offer3         Agent  Four-Door Car      Medsize
# 2        L3           Offer1         Agent   Two-Door Car      Medsize
# 3        L2           Offer1   Call Center            SUV      Medsize
# 4        L1           Offer1         Agent  Four-Door Car      Medsize
# ...     ...              ...           ...            ...          ...
# 9129     L1           Offer2           Web  Four-Door Car      Medsize
# 9130     L3           Offer1        Branch  Four-Door Car      Medsize
# 9131     L2           Offer1        Branch  Four-Door Car      Medsize
# 9132     L2           Offer3        Branch  Four-Door Car        Large
# 9133     L3           Offer4   Call Center   Two-Door Car      Medsize
#
# [9134 rows x 15 columns]

# %%
categorical_df.dtypes
# Out:
# state                        object
# response                     object
# coverage                     object
# education                    object
# effective_to_date    datetime64[ns]
# employment_status            object
# gender                       object
# location_code                object
# marital_status               object
# policy_type                  object
# policy                       object
# renew_offer_type             object
# sales_channel                object
# vehicle_class                object
# vehicle_size                 object
# dtype: object

# %%
# Plotting the Categorical Variables into Graphs 
def cntplot_cat(df):
    for col in df.columns:
        title = f"{col} : {len(df[col].unique())} categories"
        sns.countplot(df[col])
        plt.xticks(rotation=45)
        plt.xlabel(None)          
        plt.title(title,fontsize=20)
        plt.show()
    return None
   
plt.figure(figsize = (10,5))
cntplot_cat(categorical_df)
# Out:
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Cleaning numerical 
numerical_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 0                             0                   1          384.811147
# 1                             0                   8         1131.464935
# 2                             0                   2          566.472247
# 3                             0                   7          529.881344
# 4                             0                   1          138.130879
# ...                         ...                 ...                 ...
# 9129                          0                   2          198.234764
# 9130                          0                   1          379.200000
# 9131                          3                   2          790.784983
# 9132                          0                   3          691.200000
# 9133                          0                   1          369.600000
#
# [9134 rows x 8 columns]

# %%
numerical_df.dtypes
# Out:
# customer_lifetime_value          float64
# income                             int64
# monthly_premium_auto               int64
# months_since_last_claim            int64
# months_since_policy_inception      int64
# number_of_open_complaints          int64
# number_of_policies                 int64
# total_claim_amount               float64
# dtype: object

# %%
numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_lifetime_value        9134 non-null   float64
#  1   income                         9134 non-null   int64
#  2   monthly_premium_auto           9134 non-null   int64
#  3   months_since_last_claim        9134 non-null   int64
#  4   months_since_policy_inception  9134 non-null   int64
#  5   number_of_open_complaints      9134 non-null   int64
#  6   number_of_policies             9134 non-null   int64
#  7   total_claim_amount             9134 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 571.0 KB

# %%
for col in numerical_df.columns:
    print(len(numerical_df[col].unique()))
# Out:
# 8041
# 5694
# 202
# 36
# 100
# 6
# 9
# 5106

# %%
# Continuous and Discrete lists
discrete_list = []
continuous_list = []
for col in numerical_df.columns:
    if len(numerical_df[col].unique()) < (customer_df.shape[0] * 0.03):
        discrete_list.append(col)
    else: 
        continuous_list.append(col)
display(discrete_list)
display(continuous_list)
# Out:
# ['monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies']
# ['customer_lifetime_value', 'income', 'total_claim_amount']

# %%
def c_d_dif(df):
    discrete_list = []
    continuous_list = []
    for col in df.columns:
        if len(df[col].unique()) < (customer_df.shape[0] * 0.03):
            discrete_list.append(col)
        else: 
            continuous_list.append(col)
    return discrete_list,continuous_list

# %%
discrete_list,continuous_list = c_d_dif(numerical_df)

# %%
discrete_df = numerical_df[discrete_list]
discrete_df
# Out:
#       monthly_premium_auto  months_since_last_claim  \
# 0                       69                       32
# 1                       94                       13
# 2                      108                       18
# 3                      106                       18
# 4                       73                       12
# ...                    ...                      ...
# 9129                    73                       18
# 9130                    79                       14
# 9131                    85                        9
# 9132                    96                       34
# 9133                    77                        3
#
#       months_since_policy_inception  number_of_open_complaints  \
# 0                                 5                          0
# 1                                42                          0
# 2                                38                          0
# 3                                65                          0
# 4                                44                          0
# ...                             ...                        ...
# 9129                             89                          0
# 9130                             28                          0
# 9131                             37                          3
# 9132                              3                          0
# 9133                             90                          0
#
#       number_of_policies
# 0                      1
# 1                      8
# 2                      2
# 3                      7
# 4                      1
# ...                  ...
# 9129                   2
# 9130                   1
# 9131                   2
# 9132                   3
# 9133                   1
#
# [9134 rows x 5 columns]

# %%
continuous_df = numerical_df[continuous_list]
continuous_df
# Out:
#       customer_lifetime_value  income  total_claim_amount
# 0                 2763.519279   56274          384.811147
# 1                 6979.535903       0         1131.464935
# 2                12887.431650   48767          566.472247
# 3                 7645.861827       0          529.881344
# 4                 2813.692575   43836          138.130879
# ...                       ...     ...                 ...
# 9129             23405.987980   71941          198.234764
# 9130              3096.511217   21604          379.200000
# 9131              8163.890428       0          790.784983
# 9132              7524.442436   21941          691.200000
# 9133              2611.836866       0          369.600000
#
# [9134 rows x 3 columns]

# %%
# Plotting the Numerical Variables into Graphs 
# Discrete Variables Plots
plt.figure(figsize = (10,5))
for column in numerical_df[discrete_list]:
    sns.distplot(numerical_df[column])
    plt.show()
# Out:
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Continuous Variables Plots
plt.figure(figsize = (10,5))
for column in numerical_df[continuous_list]:
    sns.histplot(numerical_df[column])
    plt.show()

# %%
# I am checking discrete where i found outliers. (monthly_premium_auto)
sns.boxplot(numerical_df['monthly_premium_auto'])
plt.show()
# Out:
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# I am checking for the continuous where i found outliers.
for column in numerical_df[continuous_list]:
    sns.boxplot(numerical_df[column])
    plt.show()
# Out:
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# To deal with the Outliers we can just remove them with the iqr approach as in this example: 
iqr = np.percentile(numerical_df['monthly_premium_auto'],75) - np.percentile(numerical_df['monthly_premium_auto'],25)
upper_limit = np.percentile(numerical_df['monthly_premium_auto'],75) + 1.5*iqr
lower_limit = np.percentile(numerical_df['monthly_premium_auto'],25) - 1.5*iqr

# %%
no_outliers = numerical_df[(numerical_df['monthly_premium_auto']>lower_limit) & (numerical_df['monthly_premium_auto']<upper_limit)].copy()
sns.displot(no_outliers['monthly_premium_auto'])
plt.show()

# %%
iqr = np.percentile(numerical_df['customer_lifetime_value'],75) - np.percentile(numerical_df['customer_lifetime_value'],25)
upper_limit = np.percentile(numerical_df['customer_lifetime_value'],75) + 1.5*iqr
lower_limit = np.percentile(numerical_df['customer_lifetime_value'],25) - 1.5*iqr

# %%
no_outliers = numerical_df[(numerical_df['customer_lifetime_value']>lower_limit) & (numerical_df['customer_lifetime_value']<upper_limit)].copy()
sns.displot(no_outliers['customer_lifetime_value'])
plt.show()

# %%
iqr = np.percentile(numerical_df['income'],75) - np.percentile(numerical_df['income'],25)
upper_limit = np.percentile(numerical_df['income'],75) + 1.5*iqr
lower_limit = np.percentile(numerical_df['income'],25) - 1.5*iqr

# %%
no_outliers = numerical_df[(numerical_df['income']>lower_limit) & (numerical_df['income']<upper_limit)].copy()
sns.displot(no_outliers['income'])
plt.show()

# %%
iqr = np.percentile(numerical_df['total_claim_amount'],75) - np.percentile(numerical_df['total_claim_amount'],25)
upper_limit = np.percentile(numerical_df['total_claim_amount'],75) + 1.5*iqr
lower_limit = np.percentile(numerical_df['total_claim_amount'],25) - 1.5*iqr

# %%
no_outliers = numerical_df[(numerical_df['total_claim_amount']>lower_limit) & (numerical_df['total_claim_amount']<upper_limit)].copy()
sns.displot(no_outliers['total_claim_amount'])
plt.show()

# %%
numerical_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 0                             0                   1          384.811147
# 1                             0                   8         1131.464935
# 2                             0                   2          566.472247
# 3                             0                   7          529.881344
# 4                             0                   1          138.130879
# ...                         ...                 ...                 ...
# 9129                          0                   2          198.234764
# 9130                          0                   1          379.200000
# 9131                          3                   2          790.784983
# 9132                          0                   3          691.200000
# 9133                          0                   1          369.600000
#
# [9134 rows x 8 columns]

# %%
no_outliers
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# 5                 8256.297800   62902                    69
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# 5                          14                             94
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 0                             0                   1          384.811147
# 2                             0                   2          566.472247
# 3                             0                   7          529.881344
# 4                             0                   1          138.130879
# 5                             0                   2          159.383042
# ...                         ...                 ...                 ...
# 9129                          0                   2          198.234764
# 9130                          0                   1          379.200000
# 9131                          3                   2          790.784983
# 9132                          0                   3          691.200000
# 9133                          0                   1          369.600000
#
# [8681 rows x 8 columns]

# %% [markdown]
# # Lab | Comparing regression models

# %%
# Concatenate Numerical and Categorical dataframes into one dataframe called data.
data = pd.concat([categorical_df, no_outliers], axis=1)
data = data.dropna(axis=0)
display(data.shape)
display(data.head())
display(data.tail())
# Out:
# (8681, 23)
#         state response coverage education effective_to_date employment_status  \
# 0  Washington       No    Basic  Bachelor        2011-02-24          Employed
# 2      Nevada       No  Premium  Bachelor        2011-02-19          Employed
# 3  California       No    Basic  Bachelor        2011-01-20        Unemployed
# 4  Washington       No    Basic  Bachelor        2011-02-03          Employed
# 5      Oregon      Yes    Basic  Bachelor        2011-01-25          Employed
#
#   gender location_code marital_status     policy_type  ...  vehicle_class  \
# 0      F      Suburban        Married  Corporate Auto  ...   Two-Door Car
# 2      F      Suburban        Married   Personal Auto  ...   Two-Door Car
# 3      M      Suburban        Married  Corporate Auto  ...            SUV
# 4      M         Rural         Single   Personal Auto  ...  Four-Door Car
# 5      F         Rural        Married   Personal Auto  ...   Two-Door Car
#
#   vehicle_size customer_lifetime_value   income monthly_premium_auto  \
# 0      Medsize             2763.519279  56274.0                 69.0
# 2      Medsize            12887.431650  48767.0                108.0
# 3      Medsize             7645.861827      0.0                106.0
# 4      Medsize             2813.692575  43836.0                 73.0
# 5      Medsize             8256.297800  62902.0                 69.0
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                     32.0                            5.0
# 2                     18.0                           38.0
# 3                     18.0                           65.0
# 4                     12.0                           44.0
# 5                     14.0                           94.0
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                        0.0                 1.0          384.811147
# 2                        0.0                 2.0          566.472247
# 3                        0.0                 7.0          529.881344
# 4                        0.0                 1.0          138.130879
# 5                        0.0                 2.0          159.383042
#
# [5 rows x 23 columns]
#            state response  coverage education effective_to_date  \
# 9129  California       No     Basic  Bachelor        2011-02-10
# 9130  California      Yes  Extended   College        2011-02-12
# 9131  California       No  Extended  Bachelor        2011-02-06
# 9132  California       No  Extended   College        2011-02-03
# 9133  California       No  Extended   College        2011-02-14
#
#      employment_status gender location_code marital_status     policy_type  \
# 9129          Employed      M         Urban        Married   Personal Auto
# 9130          Employed      F      Suburban       Divorced  Corporate Auto
# 9131        Unemployed      M      Suburban         Single  Corporate Auto
# 9132          Employed      M      Suburban        Married   Personal Auto
# 9133        Unemployed      M      Suburban         Single  Corporate Auto
#
#       ...  vehicle_class vehicle_size customer_lifetime_value   income  \
# 9129  ...  Four-Door Car      Medsize            23405.987980  71941.0
# 9130  ...  Four-Door Car      Medsize             3096.511217  21604.0
# 9131  ...  Four-Door Car      Medsize             8163.890428      0.0
# 9132  ...  Four-Door Car        Large             7524.442436  21941.0
# 9133  ...   Two-Door Car      Medsize             2611.836866      0.0
#
#      monthly_premium_auto  months_since_last_claim  \
# 9129                 73.0                     18.0
# 9130                 79.0                     14.0
# 9131                 85.0                      9.0
# 9132                 96.0                     34.0
# 9133                 77.0                      3.0
#
#       months_since_policy_inception  number_of_open_complaints  \
# 9129                           89.0                        0.0
# 9130                           28.0                        0.0
# 9131                           37.0                        3.0
# 9132                            3.0                        0.0
# 9133                           90.0                        0.0
#
#       number_of_policies  total_claim_amount
# 9129                 2.0          198.234764
# 9130                 1.0          379.200000
# 9131                 2.0          790.784983
# 9132                 3.0          691.200000
# 9133                 1.0          369.600000
#
# [5 rows x 23 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8681 entries, 0 to 9133
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          8681 non-null   object
#  1   response                       8681 non-null   object
#  2   coverage                       8681 non-null   object
#  3   education                      8681 non-null   object
#  4   effective_to_date              8681 non-null   datetime64[ns]
#  5   employment_status              8681 non-null   object
#  6   gender                         8681 non-null   object
#  7   location_code                  8681 non-null   object
#  8   marital_status                 8681 non-null   object
#  9   policy_type                    8681 non-null   object
#  10  policy                         8681 non-null   object
#  11  renew_offer_type               8681 non-null   object
#  12  sales_channel                  8681 non-null   object
#  13  vehicle_class                  8681 non-null   object
#  14  vehicle_size                   8681 non-null   object
#  15  customer_lifetime_value        8681 non-null   float64
#  16  income                         8681 non-null   float64
#  17  monthly_premium_auto           8681 non-null   float64
#  18  months_since_last_claim        8681 non-null   float64
#  19  months_since_policy_inception  8681 non-null   float64
#  20  number_of_open_complaints      8681 non-null   float64
#  21  number_of_policies             8681 non-null   float64
#  22  total_claim_amount             8681 non-null   float64
# dtypes: datetime64[ns](1), float64(8), object(14)
# memory usage: 1.6+ MB

# %%
data.dtypes
# Out:
# state                                    object
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employment_status                        object
# gender                                   object
# location_code                            object
# marital_status                           object
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# sales_channel                            object
# vehicle_class                            object
# vehicle_size                             object
# customer_lifetime_value                 float64
# income                                  float64
# monthly_premium_auto                    float64
# months_since_last_claim                 float64
# months_since_policy_inception           float64
# number_of_open_complaints               float64
# number_of_policies                      float64
# total_claim_amount                      float64
# dtype: object

# %%
for col in data.columns:
    print(data[col].unique())
# Out:
# ['Washington' 'Nevada' 'California' 'Oregon' 'Arizona']
# ['No' 'Yes']
# ['Basic' 'Premium' 'Extended']
# ['Bachelor' 'College' 'Masters' 'High School or Below']
# ['2011-02-24T00:00:00.000000000' '2011-02-19T00:00:00.000000000'
#  '2011-01-20T00:00:00.000000000' '2011-02-03T00:00:00.000000000'
#  '2011-01-25T00:00:00.000000000' '2011-01-18T00:00:00.000000000'
#  '2011-01-26T00:00:00.000000000' '2011-02-17T00:00:00.000000000'
#  '2011-02-21T00:00:00.000000000' '2011-01-06T00:00:00.000000000'
#  '2011-02-06T00:00:00.000000000' '2011-01-10T00:00:00.000000000'
#  '2011-01-17T00:00:00.000000000' '2011-01-05T00:00:00.000000000'
#  '2011-02-27T00:00:00.000000000' '2011-01-14T00:00:00.000000000'
#  '2011-01-21T00:00:00.000000000' '2011-02-05T00:00:00.000000000'
#  '2011-01-29T00:00:00.000000000' '2011-02-28T00:00:00.000000000'
#  '2011-02-12T00:00:00.000000000' '2011-02-02T00:00:00.000000000'
#  '2011-02-07T00:00:00.000000000' '2011-01-22T00:00:00.000000000'
#  '2011-02-13T00:00:00.000000000' '2011-01-15T00:00:00.000000000'
#  '2011-01-08T00:00:00.000000000' '2011-01-11T00:00:00.000000000'
#  '2011-01-28T00:00:00.000000000' '2011-02-08T00:00:00.000000000'
#  '2011-02-23T00:00:00.000000000' '2011-01-31T00:00:00.000000000'
#  '2011-01-02T00:00:00.000000000' '2011-02-16T00:00:00.000000000'
#  '2011-01-27T00:00:00.000000000' '2011-01-23T00:00:00.000000000'
#  '2011-01-09T00:00:00.000000000' '2011-02-11T00:00:00.000000000'
#  '2011-02-01T00:00:00.000000000' '2011-02-15T00:00:00.000000000'
#  '2011-02-26T00:00:00.000000000' '2011-01-16T00:00:00.000000000'
#  '2011-01-01T00:00:00.000000000' '2011-02-10T00:00:00.000000000'
#  '2011-01-24T00:00:00.000000000' '2011-02-25T00:00:00.000000000'
#  '2011-01-12T00:00:00.000000000' '2011-02-09T00:00:00.000000000'
#  '2011-01-19T00:00:00.000000000' '2011-01-04T00:00:00.000000000'
#  '2011-02-14T00:00:00.000000000' '2011-02-20T00:00:00.000000000'
#  '2011-02-18T00:00:00.000000000' '2011-01-03T00:00:00.000000000'
#  '2011-01-13T00:00:00.000000000' '2011-02-04T00:00:00.000000000'
#  '2011-01-30T00:00:00.000000000' '2011-02-22T00:00:00.000000000'
#  '2011-01-07T00:00:00.000000000']
# ['Employed' 'Unemployed' 'Other']
# ['F' 'M']
# ['Suburban' 'Rural' 'Urban']
# ['Married' 'Single' 'Divorced']
# ['Corporate Auto' 'Personal Auto' 'Special Auto']
# [' L3' ' L2' ' L1']
# ['Offer1' 'Offer2' 'Offer4' 'Offer3']
# ['Agent' 'Call Center' 'Web' 'Branch']
# ['Two-Door Car' 'SUV' 'Four-Door Car' 'Premium']
# ['Medsize' 'Small' 'Large']
# [ 2763.519279 12887.43165   7645.861827 ...  8163.890428  7524.442436
#   2611.836866]
# [56274. 48767.     0. ... 66367. 71941. 21941.]
# [ 69. 108. 106.  73.  67. 101.  71.  93. 110.  70.  64.  72.  74.  79.
#   61. 111. 139.  80.  63. 237.  65.  62. 117.  91.  90.  66.  99. 103.
#  172.  92. 104. 113. 124. 105.  94. 100. 112.  97.  95. 102. 186.  77.
#   96.  76. 119.  88. 109. 107. 130.  85.  98. 133.  86.  78.  83.  68.
#  192. 118.  89. 140. 168. 126. 127.  82. 115. 114. 138.  81. 150. 123.
#  190. 116. 159.  84. 152. 136. 135. 128. 225. 132. 121. 154. 156.  87.
#  244. 183. 176. 230. 129. 177. 131. 137. 161. 147. 165. 125. 193. 188.
#  196. 160. 134. 182. 173. 285. 148. 199. 171. 198. 175. 167. 194. 164.
#  181. 180. 142. 248. 151. 213. 145. 185. 153. 141. 170. 122. 143. 197.
#  166. 187. 189. 245. 191. 195. 216. 149. 144. 179. 158. 223. 146. 178.
#  184. 155. 229. 201. 157. 253. 296. 235. 247. 169. 239. 249. 174.]
# [32. 18. 12. 14.  0. 13. 17. 23. 27.  9. 21. 11. 31.  8.  4. 30. 22. 15.
#  33.  1. 19. 28. 10.  7.  3.  5. 20. 24. 29. 34.  6. 35.  2. 16. 26. 25.]
# [ 5. 38. 65. 44. 94. 13. 68.  3.  7. 87. 82. 25. 10. 50. 59.  1. 21. 49.
#  91. 47. 64. 54.  6. 14. 56. 17. 42. 40. 62. 86. 79. 15. 32. 28. 16.  4.
#  57. 77. 95. 26. 53. 12. 98. 36. 71. 60. 20.  0. 27. 48. 33. 83. 30. 69.
#  90. 81. 84. 88. 18. 11. 85. 93. 34. 89.  2. 70. 37. 43.  8. 35. 99. 55.
#  75. 51. 92. 29. 63. 61. 46. 41. 31. 45. 67. 22. 23.  9. 72. 96. 58. 66.
#  73. 39. 19. 97. 52. 76. 78. 80. 74. 24.]
# [0. 2. 1. 3. 5. 4.]
# [1. 2. 7. 9. 4. 8. 3. 6. 5.]
# [384.811147 566.472247 529.881344 ... 541.282007 198.234764 790.784983]

# %% [markdown]
# #### 1. In this final lab, we will model our data. Import sklearn train_test_split and separate the data.

# %%
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr_matrix=data.corr()  
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# #### 2. Separate X_train and X_test into numerical and categorical (X_train_cat , X_train_num , X_test_cat , X_test_num)

# %%
y = data['total_claim_amount']
X = data.drop(['total_claim_amount'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1224)

display(X_train.shape)
display(X_test.shape)
display(y_train.shape)
display(y_test.shape)
# Out:
# (6944, 22)
# (1737, 22)
# (6944,)
# (1737,)

# %%
X_train_cat = X_train.select_dtypes(['object'])
X_test_cat = X_test.select_dtypes(['object'])

X_train_num = X_train.select_dtypes(np.number)
X_test_num = X_test.select_dtypes(np.number)

display(X_train_cat.shape)
display(X_test_cat.shape)
display(X_train_num.shape)
display(X_test_num.shape)
# Out:
# (6944, 14)
# (1737, 14)
# (6944, 7)
# (1737, 7)

# %% [markdown]
# #### 3. Use X_train_num to fit scalers. Transform BOTH X_train_num and X_test_num.

# %%
transformer = MinMaxScaler().fit(X_train_num)
x_train_num_norm = transformer.transform(X_train_num)
print(x_train_num_norm.shape)
x_train_num_norm
pd.DataFrame(x_train_num_norm, columns=X_train_num.columns)
# Out:
# (6944, 7)
#       customer_lifetime_value    income  monthly_premium_auto  \
# 0                    0.088784  0.961803              0.153191
# 1                    0.041982  0.761715              0.234043
# 2                    0.060022  0.386914              0.055319
# 3                    0.015505  0.620298              0.051064
# 4                    0.077496  0.921245              0.114894
# ...                       ...       ...                   ...
# 6939                 0.011888  0.634831              0.025532
# 6940                 0.062445  0.686710              0.068085
# 6941                 0.074438  0.000000              0.008511
# 6942                 0.055296  0.678109              0.034043
# 6943                 0.107832  0.000000              0.293617
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                    0.257143                       0.919192
# 1                    0.428571                       0.808081
# 2                    0.028571                       0.222222
# 3                    0.057143                       0.595960
# 4                    0.200000                       0.383838
# ...                       ...                            ...
# 6939                 0.000000                       0.717172
# 6940                 0.200000                       0.606061
# 6941                 0.000000                       0.888889
# 6942                 0.028571                       0.787879
# 6943                 0.914286                       0.383838
#
#       number_of_open_complaints  number_of_policies
# 0                           0.0               0.375
# 1                           0.0               0.000
# 2                           0.0               0.625
# 3                           0.0               0.000
# 4                           0.0               0.500
# ...                         ...                 ...
# 6939                        0.0               0.000
# 6940                        0.0               0.875
# 6941                        0.2               0.125
# 6942                        0.0               1.000
# 6943                        0.0               0.375
#
# [6944 rows x 7 columns]

# %%
x_test_num_norm = transformer.transform(X_test_num)
print(x_test_num_norm.shape)
x_test_num_norm
pd.DataFrame(x_test_num_norm, columns=X_test_num.columns)
# Out:
# (1737, 7)
#       customer_lifetime_value    income  monthly_premium_auto  \
# 0                    0.045830  0.614807              0.008511
# 1                    0.029451  0.279113              0.174468
# 2                    0.027736  0.000000              0.187234
# 3                    0.117115  0.712825              0.080851
# 4                    0.324152  0.864974              0.017021
# ...                       ...       ...                   ...
# 1732                 0.102934  0.977866              0.046809
# 1733                 0.187497  0.000000              0.097872
# 1734                 0.011481  0.834759              0.021277
# 1735                 0.368121  0.184985              0.221277
# 1736                 0.012294  0.588392              0.029787
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                    0.457143                       0.656566
# 1                    0.142857                       0.575758
# 2                    0.371429                       0.222222
# 3                    0.800000                       0.858586
# 4                    0.257143                       0.696970
# ...                       ...                            ...
# 1732                 0.628571                       0.141414
# 1733                 1.000000                       0.424242
# 1734                 0.571429                       0.181818
# 1735                 0.285714                       0.151515
# 1736                 0.371429                       0.989899
#
#       number_of_open_complaints  number_of_policies
# 0                           1.0               0.250
# 1                           0.0               0.000
# 2                           0.0               0.000
# 3                           0.0               0.125
# 4                           0.0               0.125
# ...                         ...                 ...
# 1732                        0.0               0.125
# 1733                        0.0               0.125
# 1734                        0.0               0.000
# 1735                        0.0               0.125
# 1736                        0.0               0.000
#
# [1737 rows x 7 columns]

# %% [markdown]
# #### 4. Encode the categorical variables X_train_cat and X_test_cat

# %%
# One hot encoding for the following variables: 'state','marital_status','policy_type','policy','renew_offer_type','sales_channel' & 'vehicle_class'
onehot_train = X_train_cat.drop(['coverage','employment_status','location_code','vehicle_size'],axis = 1)
onehot_test = X_test_cat.drop(['coverage','employment_status','location_code','vehicle_size'],axis = 1)

# %%
encoder = OneHotEncoder(handle_unknown ='error', drop='first').fit(onehot_train)
X_train_cat_encoded  = encoder.transform(onehot_train).toarray()
X_test_cat_encoded = encoder.transform(onehot_test).toarray()

# %%
# Ordinal encoding for: reponse, coverage, employment status, location code and vehicle size 
ordinal_train = X_train_cat.drop(['state','education','gender','marital_status','policy_type','policy','renew_offer_type','sales_channel','vehicle_class'],axis = 1)
ordinal_test = X_test_cat.drop(['state','education','gender','marital_status','policy_type','policy','renew_offer_type','sales_channel','vehicle_class'],axis = 1)
ordinal_train.head()
ordinal_test.head()
# Out:
#      response  coverage employment_status location_code vehicle_size
# 899        No     Basic          Employed      Suburban        Small
# 5335       No   Premium             Other      Suburban      Medsize
# 1169       No   Premium        Unemployed      Suburban      Medsize
# 5854       No  Extended          Employed         Urban      Medsize
# 4849       No     Basic          Employed         Urban        Small

# %%
ordinal_train['response'].value_counts()
# Out:
# No     5942
# Yes    1002
# Name: response, dtype: int64

# %%
ordinal_test['response'].value_counts()
# Out:
# No     1491
# Yes     246
# Name: response, dtype: int64

# %%
enc = OrdinalEncoder()
ordinal_train[['response']] = enc.fit_transform(ordinal_train[['response']])
ordinal_test[['response']] = enc.fit_transform(ordinal_test[['response']])

# %%
ordinal_train['response'].value_counts()
# Out:
# 0.0    5942
# 1.0    1002
# Name: response, dtype: int64

# %%
ordinal_test['response'].value_counts()
# Out:
# 0.0    1491
# 1.0     246
# Name: response, dtype: int64

# %%
ordinal_train['coverage'].value_counts()
# Out:
# Basic       4386
# Extended    2009
# Premium      549
# Name: coverage, dtype: int64

# %%
ordinal_test['coverage'].value_counts()
# Out:
# Basic       1056
# Extended     547
# Premium      134
# Name: coverage, dtype: int64

# %%
def coverage(x):
    if 'Basic' in x:
        return '0'
    elif 'Extended' in x:
        return '1'
    else:
        return '2'
    
ordinal_train['coverage'] = ordinal_train['coverage'].apply(coverage)
ordinal_test['coverage'] = ordinal_test['coverage'].apply(coverage)

# %%
ordinal_train['coverage'].value_counts()
# Out:
# 0    4386
# 1    2009
# 2     549
# Name: coverage, dtype: int64

# %%
ordinal_test['coverage'].value_counts()
# Out:
# 0    1056
# 1     547
# 2     134
# Name: coverage, dtype: int64

# %%
ordinal_train['employment_status'].value_counts()
# Out:
# Employed      4424
# Unemployed    1673
# Other          847
# Name: employment_status, dtype: int64

# %%
ordinal_test['employment_status'].value_counts()
# Out:
# Employed      1124
# Unemployed     393
# Other          220
# Name: employment_status, dtype: int64

# %%
def employment_status(x):
    if 'Employed' in x:
        return "0"
    elif 'Unemployed' in x:
        return "1"
    else:
        return '2'
    
ordinal_train['employment_status'] = ordinal_train['employment_status'].apply(employment_status)
ordinal_test['employment_status'] = ordinal_test['employment_status'].apply(employment_status)

# %%
ordinal_train['employment_status'].value_counts()
# Out:
# 0    4424
# 1    1673
# 2     847
# Name: employment_status, dtype: int64

# %%
ordinal_test['employment_status'].value_counts()
# Out:
# 0    1124
# 1     393
# 2     220
# Name: employment_status, dtype: int64

# %%
ordinal_train['location_code'].value_counts()
# Out:
# Suburban    4284
# Rural       1399
# Urban       1261
# Name: location_code, dtype: int64

# %%
ordinal_test['location_code'].value_counts()
# Out:
# Suburban    1044
# Rural        374
# Urban        319
# Name: location_code, dtype: int64

# %%
def location_code(x):
    if 'Suburban' in x:
        return "0"
    elif 'Rural' in x:
        return "1"
    else:
        return '2'
    
ordinal_train['location_code'] = ordinal_train['location_code'].apply(location_code)
ordinal_test['location_code'] = ordinal_test['location_code'].apply(location_code)

# %%
ordinal_train['location_code'].value_counts()
# Out:
# 0    4284
# 1    1399
# 2    1261
# Name: location_code, dtype: int64

# %%
ordinal_test['location_code'].value_counts()
# Out:
# 0    1044
# 1     374
# 2     319
# Name: location_code, dtype: int64

# %%
ordinal_train['vehicle_size'].value_counts()
# Out:
# Medsize    4935
# Small      1311
# Large       698
# Name: vehicle_size, dtype: int64

# %%
ordinal_test['vehicle_size'].value_counts()
# Out:
# Medsize    1185
# Small       355
# Large       197
# Name: vehicle_size, dtype: int64

# %%
def vehicle_size(x):
    if 'Medsize' in x:
        return "0"
    elif 'Small' in x:
        return "1"
    else:
        return '2'
    
ordinal_train['vehicle_size'] = ordinal_train['vehicle_size'].apply(vehicle_size)
ordinal_test['vehicle_size'] = ordinal_test['vehicle_size'].apply(vehicle_size)

# %%
ordinal_train['vehicle_size'].value_counts()
# Out:
# 0    4935
# 1    1311
# 2     698
# Name: vehicle_size, dtype: int64

# %%
ordinal_test['vehicle_size'].value_counts()
# Out:
# 0    1185
# 1     355
# 2     197
# Name: vehicle_size, dtype: int64

# %%
ordinal_train.head()
# Out:
#       response coverage employment_status location_code vehicle_size
# 5414       0.0        1                 0             2            1
# 6564       1.0        2                 0             0            1
# 3074       0.0        0                 0             0            0
# 5214       0.0        0                 0             1            0
# 7306       0.0        1                 0             1            0

# %%
ordinal_test.head()
# Out:
#       response coverage employment_status location_code vehicle_size
# 899        0.0        0                 0             0            1
# 5335       0.0        2                 2             0            0
# 1169       0.0        2                 1             0            0
# 5854       0.0        1                 0             2            0
# 4849       0.0        0                 0             2            1

# %%
X_train_processed = np.concatenate((ordinal_train, X_train_cat_encoded,x_train_num_norm), axis=1)
X_test_processed = np.concatenate((ordinal_test, X_test_cat_encoded,x_test_num_norm), axis=1)

# %% [markdown]
# #### 5. The time variable can be useful. Try to transform its data into a useful one. Hint: Day week and month as integers might be useful.

# %%
import datetime
X_train['day_of_week'] = pd.DatetimeIndex(X_train['effective_to_date']).day_of_week
X_train.head()
# Out:
#            state response  coverage             education effective_to_date  \
# 5414      Nevada       No  Extended  High School or Below        2011-02-08
# 6564      Nevada      Yes   Premium  High School or Below        2011-02-14
# 3074     Arizona       No     Basic              Bachelor        2011-01-26
# 5214  California       No     Basic              Bachelor        2011-01-19
# 7306  California       No  Extended  High School or Below        2011-01-24
#
#      employment_status gender location_code marital_status     policy_type  \
# 5414          Employed      F         Urban         Single  Corporate Auto
# 6564          Employed      F      Suburban        Married   Personal Auto
# 3074          Employed      F      Suburban        Married   Personal Auto
# 5214          Employed      F         Rural        Married  Corporate Auto
# 7306          Employed      M         Rural       Divorced   Personal Auto
#
#       ...  vehicle_class vehicle_size customer_lifetime_value   income  \
# 5414  ...  Four-Door Car        Small             7758.588506  96162.0
# 6564  ...   Two-Door Car        Small             4669.226640  76157.0
# 3074  ...   Two-Door Car      Medsize             5860.018040  38684.0
# 5214  ...   Two-Door Car      Medsize             2921.490461  62018.0
# 7306  ...  Four-Door Car      Medsize             7013.436657  92107.0
#
#      monthly_premium_auto  months_since_last_claim  \
# 5414                 97.0                      9.0
# 6564                116.0                     15.0
# 3074                 74.0                      1.0
# 5214                 73.0                      2.0
# 7306                 88.0                      7.0
#
#       months_since_policy_inception  number_of_open_complaints  \
# 5414                           91.0                        0.0
# 6564                           80.0                        0.0
# 3074                           22.0                        0.0
# 5214                           59.0                        0.0
# 7306                           38.0                        0.0
#
#       number_of_policies  day_of_week
# 5414                 4.0            1
# 6564                 1.0            0
# 3074                 6.0            2
# 5214                 1.0            2
# 7306                 5.0            0
#
# [5 rows x 23 columns]

# %%
X_train['month_of_year'] = pd.DatetimeIndex(X_train['effective_to_date']).month
X_train.head()
# Out:
#            state response  coverage             education effective_to_date  \
# 5414      Nevada       No  Extended  High School or Below        2011-02-08
# 6564      Nevada      Yes   Premium  High School or Below        2011-02-14
# 3074     Arizona       No     Basic              Bachelor        2011-01-26
# 5214  California       No     Basic              Bachelor        2011-01-19
# 7306  California       No  Extended  High School or Below        2011-01-24
#
#      employment_status gender location_code marital_status     policy_type  \
# 5414          Employed      F         Urban         Single  Corporate Auto
# 6564          Employed      F      Suburban        Married   Personal Auto
# 3074          Employed      F      Suburban        Married   Personal Auto
# 5214          Employed      F         Rural        Married  Corporate Auto
# 7306          Employed      M         Rural       Divorced   Personal Auto
#
#       ... vehicle_size customer_lifetime_value   income monthly_premium_auto  \
# 5414  ...        Small             7758.588506  96162.0                 97.0
# 6564  ...        Small             4669.226640  76157.0                116.0
# 3074  ...      Medsize             5860.018040  38684.0                 74.0
# 5214  ...      Medsize             2921.490461  62018.0                 73.0
# 7306  ...      Medsize             7013.436657  92107.0                 88.0
#
#      months_since_last_claim  months_since_policy_inception  \
# 5414                     9.0                           91.0
# 6564                    15.0                           80.0
# 3074                     1.0                           22.0
# 5214                     2.0                           59.0
# 7306                     7.0                           38.0
#
#       number_of_open_complaints  number_of_policies  day_of_week  \
# 5414                        0.0                 4.0            1
# 6564                        0.0                 1.0            0
# 3074                        0.0                 6.0            2
# 5214                        0.0                 1.0            2
# 7306                        0.0                 5.0            0
#
#       month_of_year
# 5414              2
# 6564              2
# 3074              1
# 5214              1
# 7306              1
#
# [5 rows x 24 columns]

# %%
X_test['day_of_week'] = pd.DatetimeIndex(X_test['effective_to_date']).day_of_week
X_test.head()
# Out:
#            state response  coverage             education effective_to_date  \
# 899   California       No     Basic              Bachelor        2011-01-16
# 5335      Nevada       No   Premium               College        2011-01-19
# 1169  California       No   Premium  High School or Below        2011-02-20
# 5854  California       No  Extended              Bachelor        2011-01-06
# 4849      Nevada       No     Basic               College        2011-01-27
#
#      employment_status gender location_code marital_status     policy_type  \
# 899           Employed      F      Suburban        Married   Personal Auto
# 5335             Other      M      Suburban       Divorced   Personal Auto
# 1169        Unemployed      M      Suburban         Single   Personal Auto
# 5854          Employed      F         Urban        Married   Personal Auto
# 4849          Employed      F         Urban         Single  Corporate Auto
#
#       ...  vehicle_class vehicle_size customer_lifetime_value   income  \
# 899   ...  Four-Door Car        Small             4923.181690  61469.0
# 5335  ...  Four-Door Car      Medsize             3842.028065  27906.0
# 1169  ...  Four-Door Car      Medsize             3728.830130      0.0
# 5854  ...  Four-Door Car      Medsize             9628.702696  71269.0
# 4849  ...   Two-Door Car        Small            23295.060140  86481.0
#
#      monthly_premium_auto  months_since_last_claim  \
# 899                  63.0                     16.0
# 5335                102.0                      5.0
# 1169                105.0                     13.0
# 5854                 80.0                     28.0
# 4849                 65.0                      9.0
#
#       months_since_policy_inception  number_of_open_complaints  \
# 899                            65.0                        5.0
# 5335                           57.0                        0.0
# 1169                           22.0                        0.0
# 5854                           85.0                        0.0
# 4849                           69.0                        0.0
#
#       number_of_policies  day_of_week
# 899                  3.0            6
# 5335                 1.0            2
# 1169                 1.0            6
# 5854                 2.0            3
# 4849                 2.0            3
#
# [5 rows x 23 columns]

# %%
X_test['month_of_year'] = pd.DatetimeIndex(X_test['effective_to_date']).month
X_test.head()
# Out:
#            state response  coverage             education effective_to_date  \
# 899   California       No     Basic              Bachelor        2011-01-16
# 5335      Nevada       No   Premium               College        2011-01-19
# 1169  California       No   Premium  High School or Below        2011-02-20
# 5854  California       No  Extended              Bachelor        2011-01-06
# 4849      Nevada       No     Basic               College        2011-01-27
#
#      employment_status gender location_code marital_status     policy_type  \
# 899           Employed      F      Suburban        Married   Personal Auto
# 5335             Other      M      Suburban       Divorced   Personal Auto
# 1169        Unemployed      M      Suburban         Single   Personal Auto
# 5854          Employed      F         Urban        Married   Personal Auto
# 4849          Employed      F         Urban         Single  Corporate Auto
#
#       ... vehicle_size customer_lifetime_value   income monthly_premium_auto  \
# 899   ...        Small             4923.181690  61469.0                 63.0
# 5335  ...      Medsize             3842.028065  27906.0                102.0
# 1169  ...      Medsize             3728.830130      0.0                105.0
# 5854  ...      Medsize             9628.702696  71269.0                 80.0
# 4849  ...        Small            23295.060140  86481.0                 65.0
#
#      months_since_last_claim  months_since_policy_inception  \
# 899                     16.0                           65.0
# 5335                     5.0                           57.0
# 1169                    13.0                           22.0
# 5854                    28.0                           85.0
# 4849                     9.0                           69.0
#
#       number_of_open_complaints  number_of_policies  day_of_week  \
# 899                         5.0                 3.0            6
# 5335                        0.0                 1.0            2
# 1169                        0.0                 1.0            6
# 5854                        0.0                 2.0            3
# 4849                        0.0                 2.0            3
#
#       month_of_year
# 899               1
# 5335              1
# 1169              2
# 5854              1
# 4849              1
#
# [5 rows x 24 columns]

# %%
day_test = X_test[['effective_to_date']]
day_test['day_of_week'] = pd.DatetimeIndex(X_test['effective_to_date']).day_of_week
day_test = day_test.drop(['effective_to_date'], axis = 1)
day_test
# Out:
# C:\Users\ChristianGardel\AppData\Local\Temp\ipykernel_13548\3688765566.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_test['day_of_week'] = pd.DatetimeIndex(X_test['effective_to_date']).day_of_week
#       day_of_week
# 899             6
# 5335            2
# 1169            6
# 5854            3
# 4849            3
# ...           ...
# 1822            5
# 4578            2
# 7670            1
# 7887            5
# 2573            0
#
# [1737 rows x 1 columns]

# %%
month_test = X_test[['effective_to_date']]
month_test['month_of_year'] = pd.DatetimeIndex(X_test['effective_to_date']).month
month_test = month_test.drop(['effective_to_date'], axis = 1)
month_test
# Out:
# C:\Users\ChristianGardel\AppData\Local\Temp\ipykernel_13548\2358586214.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_test['month_of_year'] = pd.DatetimeIndex(X_test['effective_to_date']).month
#       month_of_year
# 899               1
# 5335              1
# 1169              2
# 5854              1
# 4849              1
# ...             ...
# 1822              1
# 4578              2
# 7670              1
# 7887              1
# 2573              1
#
# [1737 rows x 1 columns]

# %%
day_train = X_train[['effective_to_date']]
day_train['day_of_week'] = pd.DatetimeIndex(X_train['effective_to_date']).day_of_week
day_train = day_train.drop(['effective_to_date'], axis = 1)
day_train
# Out:
# C:\Users\ChristianGardel\AppData\Local\Temp\ipykernel_13548\4168048991.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_train['day_of_week'] = pd.DatetimeIndex(X_train['effective_to_date']).day_of_week
#       day_of_week
# 5414            1
# 6564            0
# 3074            2
# 5214            2
# 7306            0
# ...           ...
# 5874            0
# 6418            6
# 7327            4
# 585             3
# 3715            6
#
# [6944 rows x 1 columns]

# %%
month_train = X_train[['effective_to_date']]
month_train['month_of_year'] = pd.DatetimeIndex(X_train['effective_to_date']).month
month_train = month_train.drop(['effective_to_date'], axis = 1)
month_train
# Out:
# C:\Users\ChristianGardel\AppData\Local\Temp\ipykernel_13548\611900359.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_train['month_of_year'] = pd.DatetimeIndex(X_train['effective_to_date']).month
#       month_of_year
# 5414              2
# 6564              2
# 3074              1
# 5214              1
# 7306              1
# ...             ...
# 5874              2
# 6418              1
# 7327              2
# 585               1
# 3715              1
#
# [6944 rows x 1 columns]

# %% [markdown]
# #### 6. Since the model will only accept numerical data, check and make sure that every column is numerical, if some are not, change it using encoding.

# %%
X_train_processed = np.concatenate((ordinal_train, X_train_cat_encoded,x_train_num_norm,day_train,month_train), axis=1)
X_test_processed = np.concatenate((ordinal_test, X_test_cat_encoded,x_test_num_norm,day_test,month_test), axis=1)

# %% [markdown]
# #### 7. Try a simple linear regression with all the data to see whether we are getting good results.

# %%
lm = linear_model.LinearRegression()
lm.fit(X_train_processed,y_train)
# Out:
# LinearRegression()

# %%
predictions_train = lm.predict(X_train_processed)
r2_score(y_train, predictions_train)
# Out:
# 0.5154617171545672

# %%
predictions_test = lm.predict(X_test_processed)
r2_score(y_test, predictions_test)
# Out:
# 0.49288979681753087

# %% [markdown]
# #### 8. Great! Now define a function that takes a list of models and train (and tests) them so we can try a lot of them without repeating code.

# %% [markdown]
# #### 9. Use the function to check LinearRegressor and KNeighborsRegressor.

# %%
from sklearn.neighbors import KNeighborsRegressor
KNN = KNeighborsRegressor(n_neighbors=6)
KNN.fit(X_train_processed, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=6)

# %%
score = KNN.score(X_train_processed, y_train)
score
# Out:
# 0.676780288676597

# %%
score = KNN.score(X_test_processed, y_test)
score
# Out:
# 0.5387769408711188

# %% [markdown]
# #### 10 . You can check also the MLPRegressor for this task!

# %%
from sklearn.neural_network import MLPRegressor
regr = MLPRegressor(random_state=1, max_iter=200).fit(X_train_processed, y_train)
# Out:
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:679: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
regr.score(X_train_processed, y_train)
# Out:
# 0.6488771553117139

# %%
regr.score(X_test_processed, y_test)
# Out:
# 0.6355138873697248

# %% [markdown]
# #### 11 . Discuss the results

# %% [markdown]
# The MLPRegressor is performing far better than the other 2 approaches, we get a bit better train score with KNN but the test score is far better with MLPRegressor.

# %% [markdown]
# # Lab | Ramdom Variable Distributions

# %% [markdown]
# #### 1. Get the numerical variables from our dataset.

# %%
numerical_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 0                             0                   1          384.811147
# 1                             0                   8         1131.464935
# 2                             0                   2          566.472247
# 3                             0                   7          529.881344
# 4                             0                   1          138.130879
# ...                         ...                 ...                 ...
# 9129                          0                   2          198.234764
# 9130                          0                   1          379.200000
# 9131                          3                   2          790.784983
# 9132                          0                   3          691.200000
# 9133                          0                   1          369.600000
#
# [9134 rows x 8 columns]

# %% [markdown]
# #### 2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.

# %%
for i in numerical_df:
    sns.displot(numerical_df[i], kde=True)
    plt.show()

# %% [markdown]
# It seems that they all follow an exponential distribution, only month_since_policy_inception could be similar to a normal distribution, but it's not.

# %% [markdown]
# #### 3. Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
#Applying log10 transformation
def log_transfom(x):
    x = np.log10(x)
    if np.isfinite(x):
        return x
    else:
        return 0
    
customer_lifetime_value_log = numerical_df['customer_lifetime_value'].apply(log_transfom)
sns.displot(customer_lifetime_value_log)
plt.show()

# %%
income_log = numerical_df['income'].apply(log_transfom)
sns.displot(income_log)
plt.show()

# %%
mpa_log = numerical_df['monthly_premium_auto'].apply(log_transfom)
sns.displot(mpa_log)
plt.show()

# %%
months_since_last_claim_log = numerical_df['months_since_last_claim'].apply(log_transfom)
sns.displot(months_since_last_claim_log)
plt.show()

# %%
months_since_policy_inception_log = numerical_df['months_since_policy_inception'].apply(log_transfom)
sns.displot(months_since_policy_inception_log)
plt.show()

# %%
number_of_open_complaints_log = numerical_df['number_of_open_complaints'].apply(log_transfom)
sns.displot(number_of_open_complaints_log)
plt.show()

# %%
number_of_policies_log = numerical_df['number_of_policies'].apply(log_transfom)
sns.displot(number_of_policies_log)
plt.show()

# %%
total_claim_log = numerical_df['total_claim_amount'].apply(log_transfom)
sns.displot(total_claim_log)
plt.show()

# %% [markdown]
# Customer Lifetime Value and Total Claim Amount are more like a normal distibution to me after applying the log10 transformation, but others like months since policy inception are more exponential now.
